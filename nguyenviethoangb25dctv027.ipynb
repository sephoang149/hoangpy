# %%
#bài 1
a=int(input('số cần nhập'))
if a >0:
    print('là số nguyên dương' )
else:
    print('không là số nguyên dương')

# %%
#bài 2
a=int(input('số cần nhập'))
if a%2==0:
    print('là số chẵn')
else:
    print('là số lẻ')
# Out:
# là số lẻ

# %%
#bài 3
a=float(input('số cần nhập'))
if a>10:
    print('hãy nhập lại')
elif a>=8:
    print('giỏi')
elif a>=6.5:
    print('khá')
elif a>=5:
    print('trung bình')
else:
    print('yếu')
# Out:
# trung bình

# %%
#bài 4
a=int(input('hãy nhập năm cần kiểm tra'))
if a%4==0:
    print('là năm nhuận')
else:
    print('là năm không nhuậm')
# Out:
# là năm không nhuậm

# %%
#bài 5
a=float(input('số a cần nhập'))
b=float(input('số b cần nhập'))
c=float(input('số c cần nhập'))
if a>=b and a>=c :
    print('số lớn nhất là ',a)
if b>=a and b>=c :
    print('số lớn nhất là ',b)
    1
if c>=a and c>=b :
    print('số lớn nhất là ',c)
if a<=b and a<=c :
    print('số nhỏ nhất là ',a)
if b<=a and b<=c :
    print('số nhỏ nhất là ',b)
if c<=a and c<=b :
    print('số nhỏ nhất là ',c)
# Out:
# số lớn nhất là  3.0
# số nhỏ nhất là  1.0

# %%
#bài 6
a=int(input('nhập số điện cũ'))
print('chỉ số cũ là',a)
b=int(input('nhập số điện mới'))
print('chỉ số mới là',b)
c=b-a
if c>=0:
    print('số tiền cần trả là',c*1000,'đồng')
elif 100>=c>50:
    print('số tiền cần trả là',50000+(c-50)*2000,'đồng')
else:
    print('số tiền cần trả là',50000+(50)*2000+(c-100)*3500,'đồng')
# Out:
# chỉ số cũ là 123
# chỉ số mới là 298
# số tiền cần trả là 175000 đồng

# %%
#bài7
a=float(input('số a cần nhập'))
b=float(input('số b cần nhập'))
c=float(input('số c cần nhập'))
d=sorted([a,b,c], reverse= True)
print('thứ tự từ lớn đến bé',d)
e=sorted([a,b,c])
print('thứ tự từ bé đến lớn',e)
# Out:
# thứ tự từ lớn đến bé [3.0, 2.0, 1.0]
# thứ tự từ bé đến lớn [1.0, 2.0, 3.0]

# %%
#bài8
a=float(input('số  giờ làm của bạn'))
print('số giờ làm là',a)
if a<0:
    print('nhập lại')
elif 0<=a<=35:
    print('số công là',a)
else:
    print('số công là',35+(a-35)*1,5)
# Out:
# số giờ làm là 40.0
# số công là 40.0 5
